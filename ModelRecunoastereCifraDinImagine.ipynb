# %% [markdown]
# <a href="https://colab.research.google.com/github/ion22666/mysite/blob/main/ModelRecunoastereCifraDinImagine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import mnist_loader
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3659/1602471694.py in <cell line: 0>()
#       1 import mnist_loader
# ----> 2 training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
#
# /content/mnist_loader.py in load_data_wrapper()
#      24     """Return a tuple containing (training_data, validation_data, test_data)
#      25     formatted for neural network use."""
# ---> 26     tr_d, va_d, te_d = load_data()
#      27
#      28     training_inputs = [np.reshape(x, (784, 1)) for x in tr_d[0]]
#
# /content/mnist_loader.py in load_data()
#      17     """Return the MNIST data as a tuple containing the training data,
#      18     the validation data, and the test data."""
# ---> 19     with gzip.open('/data/mnist.pkl.gz', 'rb') as f:
#      20         training_data, validation_data, test_data = pickle.load(f, encoding='latin1')
# ...
